# %%
raw_students = [
    {"name": "  ayesha SHARMA  ", "roll": "101", "marks_str": "88, 72, 95, 60, 78"},
    {"name": "ROHIT verma",       "roll": "102", "marks_str": "55, 68, 49, 72, 61"},
    {"name": "  Priya Nair  ",    "roll": "103", "marks_str": "91, 85, 88, 94, 79"},
    {"name": "karan MEHTA",       "roll": "104", "marks_str": "40, 55, 38, 62, 50"},
    {"name": " Sneha pillai ",    "roll": "105", "marks_str": "75, 80, 70, 68, 85"},
]

def clean_student(record):
    # normalise name
    name = record["name"].strip().title()

    # convert roll to int
    roll = int(record["roll"])

    # convert marks_str -> list[int]
    marks_parts = record["marks_str"].split(",")
    marks = [int(part.strip()) for part in marks_parts]

    # validate name (each word only alphabetic)
    is_valid = all(part.isalpha() for part in name.split())

    if is_valid:
        print("✓ Valid name")
    else:
        print("✗ Invalid name")

    # print profile card
    print("================================")
    print(f"Student : {name}")
    print(f"Roll No : {roll}")
    print(f"Marks   : {marks}")
    print("================================")

    return {
        "name": name,
        "roll": roll,
        "marks": marks
    }

cleaned_students = []

for student in raw_students:
    cleaned_students.append(clean_student(student))

# find student with roll 103 (using while loop)
index = 0
while index < len(cleaned_students):
    student = cleaned_students[index]
    if student["roll"] == 103:
        target_name = student["name"]
        print(target_name.upper())
        print(target_name.lower())
        break
    index += 1
# Out:
# ✓ Valid name
# ...
# Student : Ayesha Sharma
# Roll No : 101
# Marks   : [88, 72, 95, 60, 78]
# ...
# ✓ Valid name
# ...
# Student : Rohit Verma
# Roll No : 102
# Marks   : [55, 68, 49, 72, 61]
# ...
# ✓ Valid name
# ...
# Student : Priya Nair
# Roll No : 103
# Marks   : [91, 85, 88, 94, 79]
# ...
# ✓ Valid name
# ...
# Student : Karan Mehta
# Roll No : 104
# Marks   : [40, 55, 38, 62, 50]
# ...
# ✓ Valid name
# ...
# Student : Sneha Pillai
# Roll No : 105
# Marks   : [75, 80, 70, 68, 85]
# ...
# PRIYA NAIR
# priya nair

# %%
student_name = "Ayesha Sharma"
subjects     = ["Math", "Physics", "CS", "English", "Chemistry"]
marks        = [88, 72, 95, 60, 78]

print(f"Grade sheet for {student_name}")
print("================================")

# Part 1: Grades
for i in range(len(subjects)):
    subject = subjects[i]
    mark    = marks[i]

    if mark >= 90:
        grade = "A+"
    elif mark >= 80:
        grade = "A"
    elif mark >= 70:
        grade = "B"
    elif mark >= 60:
        grade = "C"
    else:
        grade = "F"

    print(f"{subject}: {mark} → {grade}")

# Part 2: Analysis
total = sum(marks)
average = total / len(marks)

max_marks = max(marks)
min_marks = min(marks)

max_index = marks.index(max_marks)
min_index = marks.index(min_marks)

print("\nOverall Analysis")
print("----------------")
print(f"Total marks   : {total}")
print(f"Average marks : {round(average, 2)}")
print(f"Highest score : {subjects[max_index]} {max_marks}")
print(f"Lowest score  : {subjects[min_index]} {min_marks}")

# Part 3: While loop input
print("\nStart entering additional subjects (type 'done' to stop).")
added_count = 0

while True:
    subject_name = input("Subject name: ").strip()

    if subject_name.lower() == "done":
        break

    mark_text = input("Marks (0-100): ").strip()

    # check numeric
    if not mark_text.isdigit():
        print("Invalid marks! Please enter a number between 0 and 100.")
        continue

    mark_value = int(mark_text)

    # check range
    if mark_value < 0 or mark_value > 100:
        print("Marks out of range! Enter a value from 0 to 100.")
        continue

    subjects.append(subject_name)
    marks.append(mark_value)
    added_count += 1
    print(f"Recorded: {subject_name} → {mark_value} marks.")

print("\nNew subjects added:", added_count)

updated_total = sum(marks)
updated_average = updated_total / len(marks)
print("Updated average marks:", round(updated_average, 2))
# Out:
# Grade sheet for Ayesha Sharma
# ...
# Math: 88 → A
# Physics: 72 → B
# CS: 95 → A+
# English: 60 → C
# Chemistry: 78 → B
#
# Overall Analysis
# ----------------
# Total marks   : 393
# Average marks : 78.6
# Highest score : CS 95
# Lowest score  : English 60
#
# Start entering additional subjects (type 'done' to stop).
# Subject name: hindi
# Marks (0-100): 91
# Recorded: hindi → 91 marks.
# Subject name: economics
# Marks (0-100): 85
# Recorded: economics → 85 marks.
# Subject name: done
#
# New subjects added: 2
# Updated average marks: 81.29

# %%
class_data = [
    ("Ayesha Sharma",  [88, 72, 95, 60, 78]),
    ("Rohit Verma",    [55, 68, 49, 72, 61]),
    ("Priya Nair",     [91, 85, 88, 94, 79]),
    ("Karan Mehta",    [40, 55, 38, 62, 50]),
    ("Sneha Pillai",   [75, 80, 70, 68, 85]),
]

print("Name              | Average | Status")
print("----------------------------------------")

pass_students = []
fail_students = []
total_avg_sum = 0.0
topper_name = ""
topper_avg = 0.0

for i in range(len(class_data)):
    name, marks = class_data[i]
    avg = round(sum(marks) / len(marks), 2)

    if avg >= 60:
        status = "Pass"
        pass_students.append(name)
    else:
        status = "Fail"
        fail_students.append(name)

    print(f"{name:<18} | {avg:^7} | {status}")

    if i == 0 or avg > topper_avg:
        topper_avg = avg
        topper_name = name

    total_avg_sum += avg

print("\nPassed:", len(pass_students), pass_students)
print("Failed:", len(fail_students), fail_students)

print("Topper:", topper_name, topper_avg)

class_avg = total_avg_sum / len(class_data)
print("Class Average:", round(class_avg, 2))
# Out:
# Name              | Average | Status
# ----------------------------------------
# Ayesha Sharma      |  78.6   | Pass
# Rohit Verma        |  61.0   | Pass
# Priya Nair         |  87.4   | Pass
# Karan Mehta        |  49.0   | Fail
# Sneha Pillai       |  75.6   | Pass
#
# Passed: 4 ['Ayesha Sharma', 'Rohit Verma', 'Priya Nair', 'Sneha Pillai']
# Failed: 1 ['Karan Mehta']
# Topper: Priya Nair 87.4
# Class Average: 70.32

# %%
essay = "  python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.  "

# Step 1: strip spaces
clean_essay = essay.strip()
print("1. Clean Essay:")
print(clean_essay)

# Step 2: convert to title case
print("\n2. Title Case:")
title_version = clean_essay.title()
print(title_version)

# Step 3: count occurrences of 'python'
print("\n3. Count of 'python':")
python_count = clean_essay.count("python")
print(python_count)

# Step 4: replace 'python' with 'Python 🐍'
print("\n4. Replaced Text:")
with_emoji = clean_essay.replace("python", "Python 🐍")
print(with_emoji)

# Step 5: split into sentences
print("\n5. Sentences List:")
sentence_list = clean_essay.split(". ")
print(sentence_list)

# Step 6: print numbered sentences
print("\n6. Numbered Sentences:")
index = 1
for s in sentence_list:
    if not s.endswith("."):
        s = s + "."
    print(f"{index}. {s}")
    index += 1
# Out:
# 1. Clean Essay:
# python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.
#
# 2. Title Case:
# Python Is A Versatile Language. It Supports Object Oriented, Functional, And Procedural Programming. Python Is Widely Used In Data Science And Machine Learning.
#
# 3. Count of 'python':
# 2
#
# 4. Replaced Text:
# Python 🐍 is a versatile language. it supports object oriented, functional, and procedural programming. Python 🐍 is widely used in data science and machine learning.
#
# 5. Sentences List:
# ['python is a versatile language', 'it supports object oriented, functional, and procedural programming', 'python is widely used in data science and machine learning.']
#
# 6. Numbered Sentences:
# 1. python is a versatile language.
# 2. it supports object oriented, functional, and procedural programming.
# 3. python is widely used in data science and machine learning.
